# %%
import pandas as pd
from tabula import read_pdf

# %%
df = pd.read_csv("tabula-2024-06-FY25-MBTA-Budget.csv")

# %%
cleaned_df = df[['Unnamed: 0', 'FY23 Actuals', 'FY24 Budget', 'FY25 Budget']]
cleaned_df[['FY23 Actuals', 'FY24 Budget', 'FY25 Budget']]= cleaned_df[[ 'FY23 Actuals', 'FY24 Budget', 'FY25 Budget']].str.replace(' ', '')
cleaned_df.to_excel('2025.xlsx')
print(cleaned_df)
# Out:
#                             Unnamed: 0 Unnamed: 1 FY23 Actuals Unnamed: 3  \
# 0                             REVENUES        NaN          NaN        NaN
# 1                   Operating Revenues        NaN          NaN        NaN
# 2                     Fares, all modes          $       3 76.4          $
# 3                           Own-Source        NaN        6 9.6        NaN
# 4                        - Advertising        NaN         20.1        NaN
# 5                            - Parking        NaN         23.4        NaN
# 6                        - Real Estate        NaN         18.8        NaN
# 7                    - Other Operating        NaN          7.3        NaN
# 8              Total Operating Revenue        NaN       4 46.0        NaN
# 9               Non-Operating Revenues        NaN          NaN        NaN
# 10                 Dedicated Sales Tax        NaN     1 ,406.7        NaN
# 11         Dedicated Local Assessments        NaN       1 83.8        NaN
# ...
