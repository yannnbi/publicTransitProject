# %%
import pandas as pd

# %%
df = pd.read_csv('tabula-2024 MTA Consolidated Financial Statements.csv')
df
cleaned_df = df[['(In millions)', 'December 31,']]
cleaned_df = cleaned_df.rename(columns={
    '(In millions)': 'Items',
    'December 31,': 2024,
})
cleaned_df.head(20)
cleaned_df.to_excel('2024_financials.xlsx')

# %%
df = pd.read_csv('tabula-2024 MTA Consolidated Financial Statements.csv')
df
# cleaned_df = df[['(In millions)', 'December 31,', 'December 31,.1', 'December 31,.2']]
# cleaned_df = cleaned_df.rename(columns={
#     '(In millions)': 'Items',
#     'December 31,': 2023,
#      'December 31,.1': 2022,
#       'December 31,.2': 2021,
# })
# cleaned_df.head(20)
# cleaned_df.to_excel('2023_financials.xlsx')
# Out:
#                                         (In millions) December 31,
# 0                                                 NaN         2024
# 1                                                 NaN          NaN
# 2                                  Operating revenues          NaN
# 3                                 Passenger and tolls      $ 7,560
# 4                                               Other          948
# 5                            Total operating revenues        8,508
# 6                              Non-operating revenues          NaN
# 7                    Grants, appropriations and taxes        9,660
# 8                                               Other        3,682
# 9                        Total non-operating revenues       13,342
# 10                                     Total revenues       21,850
# 11                                 Operating expenses          NaN
# 12                                 Salaries and wages        7,273
# ...
